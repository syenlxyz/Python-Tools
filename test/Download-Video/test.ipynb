# %%
import subprocess

# %%
url = 'https://www.youtube.com/shorts/jlIKJh-QD-8'

# %%
# Supported browsers are: brave, chrome, chromium, edge, firefox, opera, safari, vivaldi, whale
browser = 'firefox'
runtime = 'node'
format = 'mp4'

# %%
subprocess.run(f'yt-dlp.exe --cookies-from-browser {browser} --js-runtimes {runtime} --merge-output-format {format} {url}')
